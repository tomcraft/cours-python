# %% [markdown]
# # Exo 1 - Charger un csv

# %%
import pandas as pd

# %%
data = pd.read_csv("https://bit.ly/world-cities-clean")
data.head(10)
# Out:
#                 name               country          subcountry  geonameid
# 0       les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1   Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2     Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3     Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4       Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696
# 5              Dubai  United Arab Emirates               Dubai     292223
# 6  Dibba Al-Fujairah  United Arab Emirates         Al Fujayrah     292231
# 7      Dibba Al-Hisn  United Arab Emirates         Al Fujayrah     292239
# 8            Sharjah  United Arab Emirates        Ash Shāriqah     292672
# 9          Ar Ruways  United Arab Emirates           Abu Dhabi     292688

# %% [markdown]
# # Exo 2 - Nommer les colonnes

# %%
data = pd.read_csv("https://bit.ly/world-cities-dirty-v1", names=(["Nom", "Pays", "Region", "GeoNameID"]))
data.head(10)
# Out:
#                  Nom                  Pays              Region  GeoNameID
# 0       les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1   Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2     Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3     Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4       Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696
# 5              Dubai  United Arab Emirates               Dubai     292223
# 6  Dibba Al-Fujairah  United Arab Emirates         Al Fujayrah     292231
# 7      Dibba Al-Hisn  United Arab Emirates         Al Fujayrah     292239
# 8            Sharjah  United Arab Emirates        Ash Shāriqah     292672
# 9          Ar Ruways  United Arab Emirates           Abu Dhabi     292688

# %% [markdown]
# # Exo 3 - Ignorer des lignes

# %%
data = pd.read_csv("https://bit.ly/world-cities-dirty-v2")
data.head(10)
# Out:
#                                                                                                                                                                                                                                   Lorem ipsum dolor sit amet  \
# Sed ut perspiciatis unde omnis iste natus error...  totam rem aperiam    eaque ipsa quae ab illo inventore veritatis et...  sed quia consequuntur magni dolores eos qui ra...  qui dolorem ipsum quia dolor sit amet  consectetur             adipisci velit
# name                                               country              subcountry                                         geonameid                                          NaN                                    NaN                                 NaN
# ...

# %%
data = pd.read_csv("https://bit.ly/world-cities-dirty-v2", skiprows=2, skipfooter=1)
data.head(10)
# Out:
# <ipython-input-17-590b52c4114e>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv("https://bit.ly/world-cities-dirty-v2", skiprows=2, skipfooter=1)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-17-590b52c4114e> in <module>
# ----> 1 data = pd.read_csv("https://bit.ly/world-cities-dirty-v2", skiprows=2, skipfooter=1)
#       2 data.head(10)
#
# ...

# %% [markdown]
# # Erreur: problème d'encodage

# %% [markdown]
# # Solution: spécifier l'encodage

# %%
data = pd.read_csv("https://bit.ly/world-cities-dirty-v2", skiprows=2, skipfooter=1, encoding="UTF-8")
data.head(10)
# Out:
# <ipython-input-18-aa044dddcf41>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv("https://bit.ly/world-cities-dirty-v2", skiprows=2, skipfooter=1, encoding="UTF-8")
#                 name               country          subcountry  geonameid
# 0       les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1   Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2     Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3     Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4       Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696
# 5              Dubai  United Arab Emirates               Dubai     292223
# 6  Dibba Al-Fujairah  United Arab Emirates         Al Fujayrah     292231
# 7      Dibba Al-Hisn  United Arab Emirates         Al Fujayrah     292239
# ...

# %% [markdown]
# # Exo 4 - df init goodpractices

# %%
data = pd.read_csv("https://bit.ly/world-cities-dirty-v2")

# %%
data.shape
# Out:
# (23021, 5)

# %%
data.dtypes
# Out:
# Lorem ipsum dolor sit amet                                                                                                                                                                                                                   object
#  consectetur adipiscing elit                                                                                                                                                                                                                 object
#  sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam                                                                                                                                                  object
#  quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident    object
# ...

# %%
data.head()
# Out:
#                                                                                                                                                                                                                                   Lorem ipsum dolor sit amet  \
# Sed ut perspiciatis unde omnis iste natus error...  totam rem aperiam    eaque ipsa quae ab illo inventore veritatis et...  sed quia consequuntur magni dolores eos qui ra...  qui dolorem ipsum quia dolor sit amet  consectetur             adipisci velit
# name                                               country              subcountry                                         geonameid                                          NaN                                    NaN                                 NaN
# ...

# %%
data.tail()
# Out:
#                                                                                                                                                                                                                                                                                                                      Lorem ipsum dolor sit amet  \
# Bindura                                            Zimbabwe                                           Mashonaland Central                                895061                                             NaN                           NaN                                                                                               NaN
# ...

# %%
data.isna().sum()
# Out:
# Lorem ipsum dolor sit amet                                                                                                                                                                                                                   23019
#  consectetur adipiscing elit                                                                                                                                                                                                                 23020
#  sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam                                                                                                                                                  23020
#  quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident    23020
# ...

# %%
data = pd.read_csv("https://bit.ly/bitcoin-data"); data.shape
# Out:
# (33, 7)

# %%
data.dtypes
# Out:
# Date           object
# Open*         float64
# High          float64
# Low           float64
# Close**       float64
# Volume        float64
# Market Cap    float64
# dtype: object

# %%
data.head()
# Out:
#           Date    Open*     High      Low  Close**        Volume    Market Cap
# 0  Jan 14 2020  8140.93  8879.51  8140.93  8827.76  4.484178e+10  1.603195e+11
# 1  Jan 13 2020  8189.77  8197.79  8079.70  8144.19  2.248291e+10  1.478905e+11
# 2  Jan 12 2020  8033.26  8200.06  8009.06  8192.49  2.290344e+10  1.487530e+11
# 3  Jan 11 2020  8162.19  8218.36  8029.64  8037.54  2.552117e+10  1.459242e+11
# 4  Jan 10 2020  7878.31  8166.55  7726.77  8166.55  2.871458e+10  1.482499e+11

# %%
data.tail()
# Out:
#                                    Date    Open*     High      Low  Close**  \
# 28                          Dec 17 2019  6931.32  6964.07  6587.97  6640.52
# 29                          Dec 16 2019  7153.66  7171.17  6903.68  6932.48
# 30                          Dec 15 2019  7124.24  7181.08  6924.38  7152.30
# 31  * Earliest data in range (UTC time)      NaN      NaN      NaN      NaN
# 32   ** Latest data in range (UTC time)      NaN      NaN      NaN      NaN
#
#           Volume    Market Cap
# 28  2.236380e+10  1.202342e+11
# 29  2.021327e+10  1.255156e+11
# 30  1.688113e+10  1.294814e+11
# 31           NaN           NaN
# 32           NaN           NaN

# %%
data.isna().sum()
# Out:
# Date          0
# Open*         2
# High          2
# Low           2
# Close**       2
# Volume        2
# Market Cap    2
# dtype: int64

# %%
data = pd.read_csv("https://bit.ly/bitcoin-data", skipfooter=2);
# Out:
# <ipython-input-34-3dd8aa663f2c>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv("https://bit.ly/bitcoin-data", skipfooter=2);

# %%
data.isna().sum()
# Out:
# Date          0
# Open*         0
# High          0
# Low           0
# Close**       0
# Volume        0
# Market Cap    0
# dtype: int64

# %% [markdown]
# # Exo 5 - créer dataframe

# %%
toy = pd.DataFrame(data={'a': [1, 2], 'b':[3,3]}); toy
# Out:
#    a  b
# 0  1  3
# 1  2  3

# %%
toy.rename(str.upper, axis='columns', inplace=True); toy
# Out:
#    A  B
# 0  1  3
# 1  2  3
